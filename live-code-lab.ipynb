# %% [markdown]
# <h1 style="text-align: center">Introduction to Data Science</h1>
# <h2 style="text-align: center">Live Lab</h2>

# %%
# Imports
import pandas as pd
import numpy as np
import api.Leaderboard as leaderboard

# %% [markdown]
# ### Please Enter Your Desired Username and Password Below:

# %%
username = 'dannydk6'
password = 'superman64'

leaderboard.signup(username=username,password=password)
# Out:
# This username already exists. Please try another one.

# %%
from datetime import datetime
datetime.utcnow()
# Out:
# datetime.datetime(2019, 10, 16, 8, 21, 13, 665131)

# %%
leaderboard.submit_question(qnumber=1,
                            response=1965,
                            username=username,
                            password=password)
# Out:
# Already answered question 1 correctly.

# %%
games = pd.read_csv('csv/soccer-data.csv')

games.sample(10)
# Out:
#              date   home_team  away_team  home_score  away_score  \
# 31811  2009-12-07       Kenya     Uganda           0           1
# 33594  2011-11-11    Cameroon      Sudan           3           1
# 19713  1996-06-29    Maldives  Singapore           0           2
# 26915  2004-09-08    Portugal    Estonia           4           0
# 7274   1969-11-05      Mexico    Belgium           1           0
# 3124   1950-07-09       Spain    Uruguay           2           2
# 3787   1955-07-24  Costa Rica  Guatemala           9           1
# 25269  2003-02-12    Bulgaria    Hungary           1           0
# 15225  1988-11-27      Kuwait     Russia           0           2
# 36873  2015-06-03      Panama    Ecuador           1           1
#
#                          tournament         city     country  neutral
# 31811                    CECAFA Cup      Nairobi       Kenya    False
# 33594                      Friendly    Marrakech     Morocco     True
# ...

# %%
x = games[games.country == 'Scotland'].shape[0]

send_question_1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b8000d628fd0> in <module>
#       1 x = games[games.country == 'Scotland'].shape[0]
#       2
# ----> 3 send_question_1()
#
# NameError: name 'send_question_1' is not defined

# %%
vals = games[['home_team','away_team','home_score','away_score']].values

# %%
vals[0]
# Out:
# array(['Scotland', 'England', 0, 0], dtype=object)

# %%
def winner(vals):
    if vals[2] > vals[3]:
        return vals[0]
    elif vals[2] < vals[3]:
        return vals[1]
    else:
        return 'Tie'

# %%
games['Winner'] = [winner(val) for val in vals]

# %%
# How many unique cities have games been played in?
games.city.unique().size
# Out:
# 1965

# %%
submit_question1(
answer=387,
username='dan',
password='danny')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-71a6a446847d> in <module>
# ----> 1 submit_question1(
#       2 answer=387,
#       3 username='dan',
#       4 password='danny')
#
# NameError: name 'submit_question1' is not defined

# %%
games['city'].unique().shape[0]
# Out:
# 1965

# %%
games['city'].value_counts().shape[0]
# Out:
# 1965

# %%
games['city'].value_counts().size
# Out:
# 1965

# %%
g
# Out:
#              date            home_team         away_team  home_score  \
# 0      1872-11-30             Scotland           England           0
# 1      1873-03-08              England          Scotland           4
# 2      1874-03-07             Scotland           England           2
# 3      1875-03-06              England          Scotland           2
# 4      1876-03-04             Scotland           England           3
# 5      1876-03-25             Scotland             Wales           4
# 6      1877-03-03              England          Scotland           1
# 7      1877-03-05                Wales          Scotland           0
# 8      1878-03-02             Scotland           England           7
# 9      1878-03-23             Scotland             Wales           9
# 10     1879-01-18              England             Wales           2
# 11     1879-04-05              England          Scotland           5
# 12     1879-04-07                Wales          Scotland           0
# ...

# %%
# How many games were played in each city?
games.groupby('city').count().loc['Glasgow','date']
# Out:
# 317

# %%
winners = games.Winner.value_counts().reset_index()

# %%
winners.columns = ['Team','Winner']

# %%
top10 = winners[winners.Team != 'Tie'].head(10)

# %%
top10['Color'] = [
                   'red',
                   'yellow',
                   'orange',
                   'green',
                   'blue',
                   'gray',
                   'black',
                   'brown',
                   'purple',
                   'pink'
                   ]

# %%
top10.Team.reset_index(drop=True) == ['Brazil','England','Germany','Argentina','Sweden','South Korea', 'Mexico','Hungary','Italy','France']
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Team, dtype: bool

# %%
import hashlib
import requests
import json

def sendAnswer1(answer):
    answer_hash = [hashlib.sha256(team.encode()).hexdigest() for team in answer]
    requests.post('localhost:8000/api/answer1',data=answer_hash)
    return answer_json

# %%
hv.Bars(top10,label='Games by Winning Team').opts(aspect=1.5, fig_inches=10, fig_bounds=(0, 0, 1, 1))
# Out:
# :Bars   [Team]   (Winner,Color)

# %%
import requests
import json

# %%
def signup(username=None,
           password=None):
    body = {'username': username,
            'email': 'mysuperemail@aol.com',
            'password': password}
    r = requests.post('http://localhost:5000/api/register',json=body)
    resp = r.json()
    return resp

# %%
signup(username='superdankest',password='memes')
# Out:
# 'ok'
